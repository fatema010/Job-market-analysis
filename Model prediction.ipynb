# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('eda.csv')

# %%
df
# Out:
#     Unnamed: 0                                          Job Title  \
# 0            0                    People Analytics Data Scientist
# 1            1                                     Data Scientist
# 2            2  Junior Data Scientist/ Data Analytics - Full T...
# 3            3                                     Data Scientist
# 4            4                                     Data Scientist
# ..         ...                                                ...
# 95          95                                  Jr Data Scientist
# 96          96     Applied Scientist - Ad Market Dynamic (Remote)
# 97          97                                     Data Scientist
# 98          98                       Data Scientist II, Associate
# 99          99                                     Data Scientist
#
#                            Salary Estimate  \
# 0    Employer Provided Salary:$51K - $124K
# 1           Employer Provided Salary:$128K
# ...
